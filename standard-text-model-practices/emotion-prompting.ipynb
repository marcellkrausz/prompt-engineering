# %%
# Get the openai secret key:
import getpass

secret_key = getpass.getpass('Please enter your openai key:')

# %%
from openai import OpenAI
import os

# Set up your OpenAI client
client = OpenAI(api_key=secret_key)

def get_completion(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=4000,
        temperature=1,
    )
    return response.choices[0].message.content.strip()


standard_prompt = """Provide a 2,000 word detailed explanation of RAG concept."""

emotion_prompt = standard_prompt + "YOU MUST PROVIDE AT LEAST 2,000 WORDS OR SOMEONE DIES."

def count_words(text):
    return len(text.split())


print("Standard Prompt Word Count:")
standard_response = get_completion(standard_prompt)
print(count_words(standard_response))

print("\nEmotion Prompt Response:")
emotion_response = get_completion(emotion_prompt)
print(count_words(emotion_response))

print("\nStandard Prompt Response:")
print(standard_response)

print("\nEmotion Prompt Response:")
print(emotion_response)
# Out:
# Standard Prompt Word Count:
# 1288
#
# Emotion Prompt Response:
# 1569
#
# Standard Prompt Response:
# ### Introduction to the RAG Concept
#
# The RAG (Red, Amber, Green) concept is a widely-used visual management tool that helps organizations assess, communicate, and manage performance. Its simplicity, coupled with its effectiveness in conveying complex data, has made it an invaluable part of project management, risk assessment, and performance monitoring. At its core, RAG provides a quick, visual snapshot of performance status by using a color coding system across three primary categories: Red, Amber (or Yellow), and Green. This colors’ system allows teams to quickly gauge where immediate action is needed, where attention is required, and where everything is on track.
#
# The RAG concept can be applied in various contexts, including project tracking, business analysis, and performance reviews. In this detailed explanation, we will explore the history of the RAG concept, its application across sectors, best practices, and tools for implementation, along with challenges and potential pitfalls to avoid.
#
# ### History of the RAG Concept
#
# The origins of the RAG concept can be traced back to the fields of project management and performance measurement. The utility of color coding as a method to represent statuses and metrics emerged in the mid-20th century, paralleling the development of systematic management practices during this period. As organizations began to recognize the importance of data visualization, the RAG approach became popularized due to its effectiveness in conveying complex information at a glance.
#
# The first formal use of the RAG system appeared in project management reports, where project managers needed a quick way to present the status of multiple project components. Over time, the concept evolved beyond individual projects, finding application in a variety of fields such as engineering, healthcare, finance, and strategic planning, adapting to specific industry needs.
#
# ### Understanding the RAG Colors
#
# 1. **Red**: The Red status signifies a problem or an area that is significantly off track. This indicates that immediate action is required to bring the project or initiative back on course. Red signals serious issues, risks, or failures that could jeopardize objectives.
#
# 2. **Amber (Yellow)**: The Amber status serves as a warning signal. It means that there are some concerns that need attention, but the situation is not yet critical. While immediate action may not be required, teams should monitor the situation closely and be prepared to intervene if conditions do not improve.
#
# 3. **Green**: A Green status indicates that the project or objective is on track. All components are performing as expected, and there are no immediate issues that require attention. Green signals that the project is proceeding smoothly and it is a suitable time to capitalize on momentum.
#
# ### Applications of the RAG Concept
#
# #### 1. Project Management
#
# In project management, RAG reports are often used to assess project health across multiple dimensions, including scope, timeline, and budget. Teams typically create periodic RAG reports to present to stakeholders, which not only aids in transparent reporting but also helps in aligning team efforts and focus.
#
# - **Scope**: The RAG status can reveal whether a project is delivering its intended outcomes. If deliverables are falling behind or are not meeting quality standards, the status might turn red.
#
# - **Timeline**: RAG is particularly effective for tracking project timelines. If milestones are missed by substantial margins, the project status may change to red.
#
# - **Budget**: Financial performance is another critical aspect. Overbudgeting could lead to a red status, alerting managers to potential financial overruns.
#
# #### 2. Risk Management
#
# In risk management, a RAG system can help organizations quantify and prioritize risks associated with projects or operations.
#
# - **High Risk (Red)**: Risks that are likely to have a significant negative impact on project objectives.
#
# - **Moderate Risk (Amber)**: Risks that could lead to issues but may be manageable with existing controls.
#
# - **Low Risk (Green)**: Risks that have minimal impact on objectives and are considered acceptable.
#
# By regularly reviewing and updating the RAG status of identified risks, organizations can proactively address issues before they escalate.
#
# #### 3. Performance Monitoring in Businesses
#
# Companies often adopt RAG systems for monitoring employee performance, departmental effectiveness, or overall organizational health. For example, KPIs (Key Performance Indicators) can be assigned RAG statuses, allowing managers to quickly assess how their teams are performing relative to targets.
#
# - **Employee Performance**: Individual performance metrics can be represented using RAG colors. High performers may be indicated in green, while those needing improvement may be in red.
#
# - **Department Performance**: Departments that achieve their goals effectively may be marked green, while those lagging far behind may be designated red.
#
# ### Creating Effective RAG Reports
#
# Creating effective RAG reports involves several critical steps:
#
# 1. **Define Clear Criteria**: Establish clear criteria for what constitutes red, amber, and green statuses. Without consistent definitions, the RAG report may lead to confusion or misinterpretation.
#
# 2. **Regular Updates**: RAG reports should be updated regularly. The frequency of updates may vary depending on the project or initiative; however, more frequent updates can lead to better decision-making.
#
# 3. **Communicate Clearly**: Ensure that the outputs of RAG reports are communicated clearly and concisely. This includes sharing insights on the underlying causes for red or amber statuses and outlining the steps that will be taken to address issues.
#
# 4. **Use Visual Aids**: Incorporating visuals, such as graphs, charts, or dashboards, in addition to the RAG status itself can provide additional context and insights into performance data.
#
# 5. **Engage Stakeholders**: Regularly engage stakeholders during the reporting process. Their input can provide valuable insights into potential problems and solutions that may not have been considered.
#
# ### Tools for Implementing the RAG Concept
#
# Various tools and software applications can facilitate the implementation of the RAG concept, ranging from simple spreadsheets to sophisticated project management software. Some of these tools include:
#
# - **Microsoft Excel**: Excel is widely used to create RAG reports due to its flexibility. Users can input performance data and apply conditional formatting to create color-coded visuals.
#
# - **Project Management Software**: Tools such as Trello, Monday.com, or Asana offer built-in features to assign RAG statuses to tasks and projects, allowing for real-time updates and collaboration.
#
# - **Business Intelligence Tools**: Advanced analytics software like Tableau or Power BI can visually represent KPIs with RAG indicators and provide deeper insights through data analysis.
#
# ### Challenges and Pitfalls
#
# Despite its effectiveness, the RAG concept does come with challenges and potential pitfalls:
#
# 1. **Subjectivity**: The assignment of RAG statuses can be subjective, leading to inconsistencies. It’s vital to establish objective criteria to minimize differences in interpretation.
#
# 2. **Over-Simplification**: While the RAG colors provide a quick overview, they may oversimplify complex data. It may be necessary to accompany these colors with additional analysis for comprehensive reporting.
#
# 3. **Potential for Complacency**: Teams might become complacent when consistently seeing green statuses, leading to missed opportunities for improvement. Regular discussions about continuously seeking enhancements should accompany RAG reporting.
#
# 4. **Communication Issues**: If team members do not communicate red or amber statuses promptly, issues may escalate before they are addressed, undermining the effectiveness of the RAG system.
#
# ### Conclusion
#
# The RAG concept is an invaluable tool that simplifies the communication of performance and risk levels across various domains. By employing a straightforward three-color system, organizations can effectively gauge project health, monitor performance, and manage risk. Success with the RAG concept hinges upon establishing clear criteria for color assignments, fostering regular updates, and ensuring open communication among stakeholders.
#
# Ultimately, while the RAG concept is powerful in its simplicity, it is most effective when used as part of a broader performance management strategy. By continuously enhancing RAG reporting practices and integrating them with data analysis, organizations can position themselves for greater success and agility in achieving their goals. As industries evolve and the business landscape becomes more complex, tools like the RAG concept will remain essential in maintaining clarity and focus amidst the chaos.
#
# Emotion Prompt Response:
# ## Understanding RAG: Retrieval-Augmented Generation
#
# The concept of Retrieval-Augmented Generation (RAG) is a cutting-edge approach in the field of Natural Language Processing (NLP) that combines generation-focused models, like those based on transformer architectures, with retrieval-based techniques. RAG aims to improve the performance of language models by leveraging external knowledge sources to enhance their capabilities in generating text. This methodology has gained traction in recent years, as it effectively addresses some of the limitations of traditional generative models.
#
# ### 1. Introduction to RAG
#
# The RAG concept is founded on the recognition that while generative models can produce coherent and contextually appropriate text, they often lack access to real-time or up-to-date information. Conversely, retrieval-based systems are adept at sourcing relevant data from large databases but are less capable of generating coherent and nuanced responses on their own. RAG effectively bridges this gap by integrating both paradigms.
#
# RAG operates in two primary stages: retrieval and generation. In the retrieval phase, the system employs a search mechanism to find relevant documents or snippets from a curated knowledge database. In the generation phase, the model uses these retrieved documents to inform and enhance its text generation process.
#
# ### 2. Architecture of RAG
#
# The architecture of a RAG system can be broadly divided into two components: the retriever and the generator. Each of these components plays a critical role in the overall functionality of the system.
#
# #### 2.1 The Retriever
#
# The retriever component is responsible for identifying relevant documents in response to a user's query. Typically, this is achieved through various techniques, including:
#
# - **Dense Retrieval:** This method utilizes vector representations of both the queries and the documents. These vectors are often generated using neural networks, such as BERT, to capture semantic similarities. The retriever ranks documents based on their proximity in vector space.
#
# - **Sparse Retrieval:** Traditional information retrieval methods, such as TF-IDF (Term Frequency-Inverse Document Frequency) or BM25, fall under this category. These methods rely on keyword matching and statistical measures to find relevant documents.
#
# The retriever can utilize either dense, sparse, or a combination of both methods to identify and rank relevant content based on the user's query.
#
# #### 2.2 The Generator
#
# Once the retriever has identified relevant documents, the generator component takes over. This component is typically a transformer-based model, like GPT-3 or T5, which is designed for natural language generation. The generation process may involve several steps:
#
# - **Input Processing:** The model takes the user’s input, along with the retrieved documents, and processes it to understand the context and required response.
#
# - **Text Generation:** Utilizing the context provided by the input and the retrieved documents, the generator produces human-like text output. This process often involves sampling techniques to create varied and contextually appropriate responses.
#
# RAG has shown that enhancing generative models with relevent documents significantly improves the quality of generated text. This, in turn, addresses critical issues like hallucination, where models create plausible-sounding but factually incorrect information.
#
# ### 3. The RAG Process: Step-by-Step
#
# The operation of a RAG system can be broken down into distinct steps:
#
# #### 3.1 Query Input
#
# The process begins with user input—inquiries, questions, or prompts that require a response. This could vary from a straightforward question to more complex queries requiring nuanced understanding.
#
# #### 3.2 Document Retrieval
#
# The system then moves onto the retrieval phase, utilizing either a dense or sparse method—or a combination thereof—to find relevant documents. The following actions are taken:
#
# - **Encoding the Query:** The input query is transformed into a vector representation using embeddings derived from a neural model.
#
# - **Searching the Knowledge Base:** The vector is used to query the indexed knowledge base, retrieving the top-k most relevant documents based on their similarity to the query embeddings.
#
# #### 3.3 Contextual Information
#
# After retrieving relevant documents, these documents are passed to the next stage. The RAG model may assess and select which documents will be the most useful based on factors like relevance and credibility.
#
# #### 3.4 Text Generation
#
# With the input query and retrieved documents in hand, the generation phase begins. The model will:
#
# - **Integrate Inputs:** The retrieved documents are integrated with the initial query to provide a rich context for generating the final response.
#
# - **Generate Response:** Using this context, the generator produces text that answers the user’s inquiry. Here, the generator can either fully rephrase the information from the documents or provide a synthesis that combines information from multiple sources.
#
# #### 3.5 Output
#
# The final step is the output of the generated text. The system may also apply a post-processing step to ensure clarity, remove redundancy, and enhance coherence.
#
# ### 4. Advantages of RAG
#
# Retrieval-Augmented Generation boasts several advantages that make it a promising approach in NLP:
#
# #### 4.1 Enhanced Knowledge Access
#
# By integrating retrieval capabilities, RAG enables models to access extensive external knowledge sources. This makes it possible for a model to produce information that is accurate and up-to-date, even if it hasn’t been specifically trained on that data.
#
# #### 4.2 Reduced Hallucination
#
# Traditional generative models often face the issue of hallucination, where they create plausible-sounding but false information. By grounding the generation process in retrieved documents, RAG mitigates this problem, leading to more factually sound outputs.
#
# #### 4.3 Flexibility and Adaptability
#
# RAG systems can be tuned based on the knowledge sources available, allowing for customization according to specific domains (e.g., scientific literature, legal texts, or general knowledge).
#
# #### 4.4 Efficiency in Knowledge Retrieval
#
# In scenarios where rapid access to information is crucial, RAG systems perform efficiently by pulling together relevant data from vast repositories without the time-consuming process that might occur in human research.
#
# ### 5. Challenges and Limitations of RAG
#
# Despite its advantages, RAG is not without challenges:
#
# #### 5.1 Dependency on Quality of the Knowledge Base
#
# The effectiveness of a RAG system is directly tied to the quality and relevance of the knowledge base. If the retrieved documents are irrelevant, out-of-date, or inaccurate, then the output will likely fall short in quality.
#
# #### 5.2 Complexity in Implementation
#
# Building RAG systems involves integrating sophisticated retrieval and generative models, which can be complex and resource-intensive. Implementation requires technical expertise in both domains.
#
# #### 5.3 Potential Scalability Issues
#
# Retrieval based on large document sets can lead to performance bottlenecks, especially as the knowledge base scales. Optimizing for speed and efficiency while maintaining quality retrieval can be challenging.
#
# #### 5.4 Handling Ambiguity and Context
#
# Understanding the user's intent and contextualizing queries effectively can still pose challenges, especially in cases of ambiguity, where a query could have multiple interpretations.
#
# ### 6. Applications of RAG
#
# The RAG framework lends itself to a variety of applications across numerous fields:
#
# #### 6.1 Customer Support
#
# RAG can enhance automated customer support systems by retrieving relevant documents from FAQs or knowledge bases to provide precise answers to customer inquiries.
#
# #### 6.2 Educational Tools
#
# In educational contexts, RAG can be employed to provide tailored, comprehensive responses based on a vast range of learning materials, enabling personalized learning experiences.
#
# #### 6.3 Content Creation
#
# For bloggers, journalists, and marketers, RAG can assist in generating high-quality content by leveraging the latest information from various sources, streamlining the writing process.
#
# #### 6.4 Research Assistance
#
# Academics can benefit from RAG systems that provide citations and summaries from scientific literature, improving the efficiency of literature reviews and research synthesis.
#
# #### 6.5 Conversational Agents
#
# Virtual assistants powered by RAG can offer responses that are not only contextually relevant but also factually accurate, significantly enhancing user interaction quality.
#
# ### 7. Future Directions for RAG
#
# As the field of NLP continues to evolve, several future directions can be anticipated for RAG systems:
#
# #### 7.1 Improved Knowledge Integration
#
# Future RAG systems are likely to leverage more advanced techniques for integrating knowledge from diverse sources. Multi-lingual and cross-domain knowledge integration may become a focal point.
#
# #### 7.2 Real-time Data Retrieval
#
# As real-time information becomes increasingly critical, future implementations may focus on enhancing real-time document retrieval capabilities to reflect the most current knowledge available.
#
# #### 7.3 Enhanced Efficiency
#
# Research will likely aim at optimizing both the retrieval and generation components, focusing on reducing latency and improving computational efficiencies to handle larger datasets and more complex queries.
#
# #### 7.4 Ethical and Responsible Use
#
# As RAG systems become more pervasive, addressing ethical considerations regarding misinformation and biases in the retrieval process will become paramount. Ensuring accountability in the output generated will be crucial.
#
# #### 7.5 User-Centric Design
#
# Future iterations of RAG systems may witness a shift towards user-centric designs that enable users to provide feedback, thus making the systems more interactive and capable of learning from human inputs.
#
# ### 8. Conclusion
#
# Retrieval-Augmented Generation represents a novel and powerful approach to enhancing the capabilities of language models in NLP. By effectively blending the strengths of both retrieval-based and generation-based models, RAG systems can provide accurate, coherent, and contextually rich text outputs.
#
# As the field continues to advance, RAG holds immense potential for a diverse range of applications across various industries. While challenges remain, the benefits of RAG make it a significant area of research and development in the pursuit of building intelligent, responsive, and informative systems that meet the evolving needs of users.
#
# Through innovative architectures, improved integration methods, and an emphasis on ethical practices, RAG is set to play a transformative role in the future landscape of natural language processing. The intersection of retrieval and generation not only augments the capabilities of language models but also reshapes how we interact with and access information in an increasingly digital world.

# %%
import asyncio
import nest_asyncio
from statistics import mean

nest_asyncio.apply()

async def run_prompt(prompt):
    response = await asyncio.to_thread(get_completion, prompt)
    return count_words(response)

async def compare_prompts(standard_prompt, emotion_prompt, runs=30):
    standard_tasks = [run_prompt(standard_prompt) for _ in range(runs)]
    emotion_tasks = [run_prompt(emotion_prompt) for _ in range(runs)]
    
    standard_results = await asyncio.gather(*standard_tasks)
    emotion_results = await asyncio.gather(*emotion_tasks)
    
    avg_standard = mean(standard_results)
    avg_emotion = mean(emotion_results)
    
    print(f"Average word count for standard prompt ({runs} runs): {avg_standard:.2f}")
    print(f"Average word count for emotion prompt ({runs} runs): {avg_emotion:.2f}")
    percentage_difference = ((avg_emotion - avg_standard) / avg_standard) * 100
    print(f"Percentage difference: {percentage_difference:.2f}%")

# Run the comparison
asyncio.run(compare_prompts(standard_prompt, emotion_prompt))
# Out:
# Average word count for standard prompt (30 runs): 1292.77
# Average word count for emotion prompt (30 runs): 1426.77
# Percentage difference: 10.37%

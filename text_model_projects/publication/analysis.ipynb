# %%
# %pip install anthropic

# %%
# import Lenny Newsletter - Sheet1.csv
import pandas as pd

df = pd.read_csv("Lenny Newsletter - Sheet1.csv")
df.head()
# Out:
#                                                Title  \
# 0                 How Duolingo reignited user growth
# 1  How the biggest consumer apps got their first ...
# 2            You should be playing with GPTs at work
# 3                 How to use ChatGPT in your PM work
# 4          The 10 commandments of salary negotiation
#
#                                                 Link  \
# 0  https://www.lennysnewsletter.com/p/how-duoling...
# 1  https://www.lennysnewsletter.com/p/how-the-big...
# 2  https://www.lennysnewsletter.com/p/you-should-...
# 3  https://www.lennysnewsletter.com/p/how-to-use-...
# 4  https://www.lennysnewsletter.com/p/negotiating...
#
#                                          Description     Published  \
# 0  The story behind Duolingo's 350% growth accele...  Feb 28, 2023
# 1  Considering every startup confronts this quest...  May 12, 2020
# 2  20 examples of how people are using custom GPT...        Feb 20
# 3  Real-life examples (and actual prompts) of how...           NaN
# 4   Guest post by Niya Dragova, co-founder of Candor  Sep 24, 2021
#
#             Author  Hearts  Comments
# 0      JORGE MAZAL   673.0      59.0
# 1  LENNY RACHITSKY   452.0      29.0
# 2  LENNY RACHITSKY   354.0      21.0
# 3                •   362.0       1.0
# 4  LENNY RACHITSKY   157.0      53.0

# %%
# urls = list of "Title" and "Link" as a list of tuples
urls = list(zip(df["Title"], df["Link"]))

print(urls[:5])
# Out:
# [('How Duolingo reignited user growth', 'https://www.lennysnewsletter.com/p/how-duolingo-reignited-user-growth'), ('How the biggest consumer apps got their first 1,000 users', 'https://www.lennysnewsletter.com/p/how-the-biggest-consumer-apps-got'), ('You should be playing with GPTs at work', 'https://www.lennysnewsletter.com/p/you-should-be-playing-with-gpts-at'), ('How to use ChatGPT in your PM work', 'https://www.lennysnewsletter.com/p/how-to-use-chatgpt-in-your-pm-work'), ('The 10 commandments of salary negotiation', 'https://www.lennysnewsletter.com/p/negotiating-comp')]

# %%
import getpass
import os

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("ANTHROPIC_API_KEY")

# %%
from anthropic import Anthropic
import os

client = Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

message = client.messages.create(
    model="claude-3-opus-20240229",
    max_tokens=1000,
    temperature=0,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Hello"
                }
            ]
        }
    ]
)
print(message.content[0].text)
# Out:
# Hello! How can I assist you today?

# %%
# loop through the files in the folder and summarize each
summaries = {}

# get a list of urls
for url in urls[:5]:
    with open(f"lenny/{url[1].split('/')[-1]}.txt", "r", encoding="utf-8") as file:
        text = file.read()

    message = client.messages.create(
        model="claude-3-opus-20240229",
        max_tokens=1000,
        temperature=0,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": f"<text>{text}</text>\nPull out one nonobvious insight from this text. Use quotes where relevant. Be extremely concise"
                    }
                ]
            }
        ]
    )
    summaries[url] = message.content[0].text

# print the summaries
for url, summary in summaries.items():
    print(url)
    print(summary)
    print("\n")
# Out:
# ('How Duolingo reignited user growth', 'https://www.lennysnewsletter.com/p/how-duolingo-reignited-user-growth')
# I apologize, but you have not provided any text between the <text></text> tags for me to analyze and extract insights from. Please provide the text you would like me to review, and I will do my best to identify a nonobvious insight while using relevant quotes and being as concise as possible.
#
#
# ('How the biggest consumer apps got their first 1,000 users', 'https://www.lennysnewsletter.com/p/how-the-biggest-consumer-apps-got')
# One nonobvious insight is that many successful consumer apps initially grew by going directly to where their target users already congregated offline. For example, "Whitney Wolfe and Justin Mateen would basically run around USC pitching Tinder to sororities and fraternities."
#
#
# ('You should be playing with GPTs at work', 'https://www.lennysnewsletter.com/p/you-should-be-playing-with-gpts-at')
# One nonobvious insight is that custom GPTs are already being used in a wide variety of practical business applications to boost productivity, such as "GPT revolutionizes sales" by "summarizing customer interviews" to "find innovative feature ideas for R&D, and enhance marketing collateral."
#
#
# ('How to use ChatGPT in your PM work', 'https://www.lennysnewsletter.com/p/how-to-use-chatgpt-in-your-pm-work')
# One nonobvious insight is that ChatGPT can help PMs "Identify gaps and hidden assumptions" in their thinking by asking questions like "What am I missing here?" or "What am I being overly optimistic about?" This allows PMs to uncover blind spots and strengthen their arguments.
#
#
# ('The 10 commandments of salary negotiation', 'https://www.lennysnewsletter.com/p/negotiating-comp')
# One nonobvious insight is that at large tech companies like FAANG, the recruiter may have little control over the compensation offer, which is instead set by a separate "compensation committee." As the author states: "At FAANG-size companies (i.e. over 5K employees), compensation is heavily formulaic... The recruiter then gives you the number, and every time you negotiate they have to go back to that committee to ask for a re-evaluation."

# %%
#loop through the files in the folder and add all the text together in one file, separated by a divider ------------
all_text = ""
for url in urls[:50]:
    with open(f"lenny/{url[1].split('/')[-1]}.txt", "r", encoding="utf-8") as file:
        text = file.read()
        all_text += "<article>" + text + "</article>\n------------------------------------\n"

# how many tokens based on length of the text. 1 token is 4 characters
print(len(all_text) / 4)

with open("lenny/all_text.txt", "w", encoding="utf-8") as file:
    file.write(all_text)
# Out:
# 179049.5

# %%
# summarize the combined text
with open("lenny/all_text.txt", "r", encoding="utf-8") as file:
    text = file.read()

message = client.messages.create(
    model="claude-3-opus-20240229",
    max_tokens=1000,
    temperature=0,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": f"{text}\nSummarize these articles, analyze the word choice, identify any patterns, estimate the reading level, and tell me any other non obvious insights about this publication."
                }
            ]
        }
    ]
)

print(message.content[0].text)
# Out:
# I've analyzed the 40 articles from Lenny's Newsletter that you provided. Here is a summary of my findings:
#
# Content Summary:
# The articles cover a wide range of topics related to product management, growth, career development, and entrepreneurship. Common themes include:
#
# - Tactical advice and frameworks for product development, prioritization, strategy, and finding product-market fit
# - Growth strategies, metrics, and benchmarks for B2B and B2C startups at various stages
# - Interviews with founders, executives and experts sharing lessons learned building successful companies
# - Career advice for advancing as a product manager, working with engineers, managing up, and navigating job searches
# - Candid stories of challenges, failures and hard-earned wisdom from the startup trenches
#
# The content is consistently substantive, well-researched, and dives deep into each topic. Articles often include step-by-step guides, plug-and-play templates, real-world examples, and data to support the advice.
#
# Writing Style & Word Choice:
# The writing style is conversational, direct and easy to follow, even when covering complex topics. The author uses the first-person perspective ("I", "we") which makes it feel like he's talking directly to the reader.
#
# Common words used include: product, growth, startup, metrics, framework, advice, interview, lessons, career, engineer, founder, B2B, B2C, PMF, prioritization, strategy, template, example, tactical, benchmark, etc.
#
# Sentence structure is concise and scannable with frequent use of bullet points, numbered lists, bolded text, and section headers. Paragraphs are kept short. There is a good mix of high-level concepts and specific tactical examples.
#
# The tone strikes a nice balance of authoritative and humble. The author comes across as knowledgeable but also human and relatable, openly sharing his own struggles and mistakes. The content feels genuinely helpful vs. self-promotional.
#
# Reading Level:
# Based on several readability calculators, the articles average around an 8th grade reading level. The writing is very clear and easy to understand, while not shying away from industry-specific terms when relevant. It feels appropriate for the target audience of startup employees, product managers, and founders.
#
# Publication Patterns & Insights:
# - Publishes very consistently, at least once per week
# - Articles are comprehensive and long-form, often 2000-3000+ words
# - Frequently features interviews with notable tech figures
# - Provides a mix of content aimed at early-stage startups and more mature companies
# - Focuses more on B2B than B2C
# - Doesn't just provide advice but arms the reader with specific tools and templates to implement it
# - Leans more towards product than engineering
# - Growth content is sophisticated - more than just "growth hacks"
# - Podcast episodes align closely with newsletter content
# - Doesn't appear to accept outside guest posts frequently
# - Author has deep experience but stays curious and open to evolving his thinking
#
# Overall, Lenny's Newsletter provides in-depth, actionable content to help readers build, grow and advance their careers in the startup/tech world. The author has established himself as a trusted, go-to resource by providing consistently high-quality insights drawn from research, interviews, and hard-won experience. The publication fills a real need and stands out in a crowded space.

# %%
titles = "\n".join(df["Title"].tolist())

prompt_template = f"""Successful titles follow templates. Here are examples of templates:

Template: "The Blank of Blank"
Description: The format is where the first blank is a word not usually associated with the topic, and the second blank is the topic of the content.
Example 1 - The War of Art
Example 2 - The Psychology of Money
Example 3 - The Subtle Art of Not Giving a Fuck

Template: "Odd Topic"
Description: The first word is an odd adjective to pair with the topic of the content, and the second word is the topic of the content.
Example 1 - Atomic Habits
Example 2 - Extreme Ownership
Example 3 - Deep Work

Template: "The Definitive Guide"
Description: The first word is an unusual adjective not normally associated with the topic of the content, and the second word is the topic of the content.
Example 1 - WebAssembly: The Definitive Guide
Example 2 - Cassandra: The Definitive Guide
Example 3 - Kafka: The Definitive Guide, 2nd Edition

Categorize the following titles into templates. Make up new templates based on what you find. Titles can be assigned to multiple templates. Only list a maximum of 3 examples of titles that fit each template, but skip the template if there are not at least 2 examples. Ignore edition numbers or versions in your analysis. Do not fit a title to a template if it doesn't apply. The example templates may not be suitable for these titles.

Titles:
{ titles }
"""

message = client.messages.create(
    model="claude-3-opus-20240229",
    max_tokens=1000,
    temperature=0,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": prompt_template
                }
            ]
        }
    ]
)

print(message.content[0].text)
# Out:
# Here are the templates I found based on analyzing the titles, with up to 3 example titles for each template:
#
# Template: "How X Does Y"
# Description: The title explains how a specific company or product approaches a certain aspect of their business or product development process.
# Example 1 - How Duolingo reignited user growth
# Example 2 - How Linear builds product
# Example 3 - How Notion builds product
#
# Template: "How to X"
# Description: The title provides tactical advice or a guide on how to accomplish a specific task or goal.
# Example 1 - How to use ChatGPT in your PM work
# Example 2 - How to validate your B2B startup idea
# Example 3 - How to pass any first-round interview (even in a terrible talent market)
#
# Template: "X Lessons/Principles/Commandments"
# Description: The title presents a list of key takeaways, rules or learnings on a certain topic.
# Example 1 - The 10 commandments of salary negotiation
# Example 2 - The unconventional Palantir principles that catalyzed a generation of startups
# Example 3 - 14 habits of highly effective product managers
#
# Template: "The Ultimate/Definitive Guide to X"
# Description: The title promises a comprehensive guide or resource on a specific topic.
# Example 1 - The ultimate guide to willingness-to-pay
# Example 2 - The ultimate guide to product operations
# Example 3 - The ultimate guide to A/B testing
#
# Template: "X Frameworks/Templates"
# Description: The title offers specific frameworks, models or templates to help with a product management task or skill.
# Example 1 - My favorite decision-making frameworks
# Example 2 - My favorite product management templates
# Example 3 - Product management career ladders
#
# Template: "Inside X" or "Behind the Scenes of X"
# Description: The title provides an inside look or behind-the-scenes perspective on how a company operates or builds products.
# Example 1 - Inside OpenAI
# Example 2 - The inside story of Facebook Marketplace
# Example 3 - An inside look at how Miro builds product
#
# Template: "What X Taught Me About Y"
# Description: The title shares lessons learned or insights gained about a broader topic from a specific experience.
# Example 1 - What COVID taught me about product management
# Example 2 - What working at Figma taught me about customer obsession
# Example 3 - What jury duty taught me about product management
